# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Data = pd.read_csv(r"C:\Users\HP\Downloads\Global_AI_Content_Impact_Dataset.csv")

# %%
Data
# Out:
#          Country  Year    Industry  AI Adoption Rate (%)  \
# 0    South Korea  2022       Media                    44
# 1          China  2025       Legal                    35
# 2            USA  2022  Automotive                    81
# 3         France  2021       Legal                    85
# 4         France  2021      Gaming                    79
# ..           ...   ...         ...                   ...
# 195      Germany  2021  Automotive                    89
# 196      Germany  2020       Media                    70
# 197       France  2023   Marketing                    66
# 198    Australia  2023  Automotive                    45
# 199  South Korea  2020  Healthcare                    11
#
#      AI-Generated Content Volume (TBs per year)  Job Loss Due to AI (%)  \
# 0                                            33                      17
# 1                                            67                      47
# 2                                            96                      11
# 3                                            94                      28
# 4                                            46                      17
# ..                                          ...                     ...
# 195                                          53                      48
# 196                                          28                      28
# 197                                          50                      40
# 198                                          20                      33
# 199                                          21                      24
#
#      Revenue Increase Due to AI (%)  Human-AI Collaboration Rate (%)  \
# 0                                46                               75
# 1                                52                               26
# 2                                46                               40
# 3                                78                               29
# 4                                 1                               22
# ..                              ...                              ...
# 195                              12                               31
# 196                              58                               59
# 197                              79                               44
# 198                              51                               42
# 199                              34                               46
#
#     Top AI Tools Used Regulation Status  Consumer Trust in AI (%)  \
# 0                Bard            Strict                        41
# 1              DALL-E            Strict                        36
# 2    Stable Diffusion          Moderate                        54
# 3              Claude          Moderate                        52
# 4          Midjourney            Strict                        42
# ..                ...               ...                       ...
# 195            DALL-E           Lenient                        77
# 196            DALL-E            Strict                        79
# 197         Synthesia           Lenient                        82
# 198            Claude            Strict                        47
# 199  Stable Diffusion          Moderate                        59
#
#      Market Share of AI Companies (%)
# 0                                  19
# 1                                  35
# 2                                  23
# 3                                   2
# 4                                  21
# ..                                ...
# 195                                44
# 196                                32
# 197                                15
# 198                                43
# 199                                33
#
# [200 rows x 12 columns]

# %%
Data["Country"].value_counts()
# Out:
# Country
# India          24
# France         24
# Japan          22
# China          21
# USA            21
# South Korea    20
# UK             20
# Germany        17
# Canada         16
# Australia      15
# Name: count, dtype: int64

# %%
sns.countplot(Data,x="Country")
plt.show()

# %%
Data["Year"].value_counts()
# Out:
# Year
# 2020    47
# 2025    38
# 2021    32
# 2022    31
# 2023    29
# 2024    23
# Name: count, dtype: int64

# %%
Data["Industry"].value_counts()
# Out:
# Industry
# Media            31
# Gaming           27
# Retail           21
# Automotive       19
# Marketing        19
# Manufacturing    18
# Legal            17
# Education        17
# Healthcare       17
# Finance          14
# Name: count, dtype: int64

# %%
Data["Top AI Tools Used"].value_counts()
# Out:
# Top AI Tools Used
# Midjourney          37
# Claude              31
# ChatGPT             31
# Stable Diffusion    27
# DALL-E              26
# Bard                24
# Synthesia           24
# Name: count, dtype: int64

# %%
Data["Regulation Status"].value_counts()
# Out:
# Regulation Status
# Moderate    76
# Lenient     63
# Strict      61
# Name: count, dtype: int64

# %%
Data
# Out:
#          Country  Year    Industry  AI Adoption Rate (%)  \
# 0    South Korea  2022       Media                    44
# 1          China  2025       Legal                    35
# 2            USA  2022  Automotive                    81
# 3         France  2021       Legal                    85
# 4         France  2021      Gaming                    79
# ..           ...   ...         ...                   ...
# 195      Germany  2021  Automotive                    89
# 196      Germany  2020       Media                    70
# 197       France  2023   Marketing                    66
# 198    Australia  2023  Automotive                    45
# 199  South Korea  2020  Healthcare                    11
#
#      AI-Generated Content Volume (TBs per year)  Job Loss Due to AI (%)  \
# 0                                            33                      17
# 1                                            67                      47
# 2                                            96                      11
# 3                                            94                      28
# 4                                            46                      17
# ..                                          ...                     ...
# 195                                          53                      48
# 196                                          28                      28
# 197                                          50                      40
# 198                                          20                      33
# 199                                          21                      24
#
#      Revenue Increase Due to AI (%)  Human-AI Collaboration Rate (%)  \
# 0                                46                               75
# 1                                52                               26
# 2                                46                               40
# 3                                78                               29
# 4                                 1                               22
# ..                              ...                              ...
# 195                              12                               31
# 196                              58                               59
# 197                              79                               44
# 198                              51                               42
# 199                              34                               46
#
#     Top AI Tools Used Regulation Status  Consumer Trust in AI (%)  \
# 0                Bard            Strict                        41
# 1              DALL-E            Strict                        36
# 2    Stable Diffusion          Moderate                        54
# 3              Claude          Moderate                        52
# 4          Midjourney            Strict                        42
# ..                ...               ...                       ...
# 195            DALL-E           Lenient                        77
# 196            DALL-E            Strict                        79
# 197         Synthesia           Lenient                        82
# 198            Claude            Strict                        47
# 199  Stable Diffusion          Moderate                        59
#
#      Market Share of AI Companies (%)
# 0                                  19
# 1                                  35
# 2                                  23
# 3                                   2
# 4                                  21
# ..                                ...
# 195                                44
# 196                                32
# 197                                15
# 198                                43
# 199                                33
#
# [200 rows x 12 columns]

# %%
Data.columns
# Out:
# Index(['Country', 'Year', 'Industry', 'AI Adoption Rate (%)',
#        'AI-Generated Content Volume (TBs per year)', 'Job Loss Due to AI (%)',
#        'Revenue Increase Due to AI (%)', 'Human-AI Collaboration Rate (%)',
#        'Top AI Tools Used', 'Regulation Status', 'Consumer Trust in AI (%)',
#        'Market Share of AI Companies (%)'],
#       dtype='object')

# %%
Country_wise_Col = Data.groupby(by="Country")["Human-AI Collaboration Rate (%)"].sum()

# %%
Country_wise_Col
# Out:
# Country
# Australia       893
# Canada          882
# China          1143
# France         1266
# Germany         845
# India          1302
# Japan           932
# South Korea    1189
# UK             1165
# USA            1202
# Name: Human-AI Collaboration Rate (%), dtype: int64

# %%
Country_wise_Col.plot(kind="bar")
plt.show()

# %%
Industry_revenue = Data.groupby(by="Industry")["Revenue Increase Due to AI (%)"].sum()

# %%
Data.dtypes
# Out:
# Country                                       object
# Year                                           int64
# Industry                                      object
# AI Adoption Rate (%)                           int64
# AI-Generated Content Volume (TBs per year)     int64
# Job Loss Due to AI (%)                         int64
# Revenue Increase Due to AI (%)                 int64
# Human-AI Collaboration Rate (%)                int64
# Top AI Tools Used                             object
# Regulation Status                             object
# Consumer Trust in AI (%)                       int64
# Market Share of AI Companies (%)               int64
# dtype: object

# %%
Industry_revenue
# Out:
# Industry
# Automotive        886
# Education         673
# Finance           509
# Gaming            899
# Healthcare        655
# Legal             711
# Manufacturing     771
# Marketing         699
# Media            1357
# Retail            794
# Name: Revenue Increase Due to AI (%), dtype: int64

# %%
sns.lineplot(Data,x="Year",y="AI Adoption Rate (%)",markers="o")

plt.show()

# %%
Country_trust = Data.groupby(by="Country")['Consumer Trust in AI (%)'].sum()

# %%
Country_trust
# Out:
# Country
# Australia       954
# Canada          993
# China          1269
# France         1405
# Germany        1104
# India          1437
# Japan          1342
# South Korea    1202
# UK             1003
# USA            1180
# Name: Consumer Trust in AI (%), dtype: int64

# %%
sns.barplot(Data,x="Country",y='Consumer Trust in AI (%)')
plt.show()

# %%
Industry_level = Data.groupby(by="Industry")['Consumer Trust in AI (%)'].sum()

# %%
Industry_level
# Out:
# Industry
# Automotive       1163
# Education         880
# Finance           786
# Gaming           1658
# Healthcare       1023
# Legal             982
# Manufacturing    1051
# Marketing        1112
# Media            1917
# Retail           1317
# Name: Consumer Trust in AI (%), dtype: int64

# %%
plt.Figure(figsize=(15,6))
sns.barplot(Data,x="Industry",y='Consumer Trust in AI (%)')
plt.tight_layout()
plt.show()

# %%
Tools_growth = Data.groupby(by="Top AI Tools Used")["Consumer Trust in AI (%)"].sum()

# %%
Tools_growth
# Out:
# Top AI Tools Used
# Bard                1544
# ChatGPT             1836
# Claude              1865
# DALL-E              1450
# Midjourney          2324
# Stable Diffusion    1416
# Synthesia           1454
# Name: Consumer Trust in AI (%), dtype: int64

# %%
Data.columns
# Out:
# Index(['Country', 'Year', 'Industry', 'AI Adoption Rate (%)',
#        'AI-Generated Content Volume (TBs per year)', 'Job Loss Due to AI (%)',
#        'Revenue Increase Due to AI (%)', 'Human-AI Collaboration Rate (%)',
#        'Top AI Tools Used', 'Regulation Status', 'Consumer Trust in AI (%)',
#        'Market Share of AI Companies (%)'],
#       dtype='object')

# %%
sns.barplot(data=Data,x="Top AI Tools Used",y='Consumer Trust in AI (%)',width=0.5)
plt.show()

# %%
Data.columns
# Out:
# Index(['Country', 'Year', 'Industry', 'AI Adoption Rate (%)',
#        'AI-Generated Content Volume (TBs per year)', 'Job Loss Due to AI (%)',
#        'Revenue Increase Due to AI (%)', 'Human-AI Collaboration Rate (%)',
#        'Top AI Tools Used', 'Regulation Status', 'Consumer Trust in AI (%)',
#        'Market Share of AI Companies (%)'],
#       dtype='object')

# %%
Market_share = pd.pivot_table(data=Data,index="Year",values='Market Share of AI Companies (%)',columns='Country',aggfunc="sum").fillna(0.0)

# %%
Market_share
# Out:
# Country  Australia  Canada  China  France  Germany  India  Japan  South Korea  \
# Year
# 2020          63.0   124.0  180.0   137.0    130.0  164.0   59.0        129.0
# 2021          51.0    21.0   88.0   133.0    123.0   86.0   74.0         71.0
# 2022          31.0   126.0  107.0    41.0     57.0   49.0  179.0         48.0
# 2023          93.0    51.0   53.0    95.0    164.0   23.0  142.0         70.0
# 2024          49.0     0.0   25.0   156.0     46.0  133.0   34.0        130.0
# 2025          68.0   130.0  116.0    91.0      0.0  224.0  109.0         99.0
#
# Country     UK    USA
# Year
# 2020     118.0   46.0
# 2021     102.0  127.0
# 2022      99.0   87.0
# 2023      46.0   64.0
# 2024      90.0   22.0
# 2025      47.0   94.0

# %%
sns.lineplot(data=Data,x="Country",y="Year",markers="o")
plt.show()
